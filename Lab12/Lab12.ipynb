# %% [markdown]
# # Experiment 12
#
# Aim: Understand the fundamentals of Generative AI and experiment
# with prompt-based tools.

# %%
import pandas as pd

columns = [
    "Class","Alcohol","Malic_Acid","Ash","Alcalinity_of_Ash",
    "Magnesium","Total_Phenols","Flavanoids","Nonflavanoid_Phenols",
    "Proanthocyanins","Color_Intensity","Hue","OD280_OD315","Proline"
]

df = pd.read_csv("wine.data", header=None, names=columns)

# Convert few rows into text
sample_text = df.head(5).to_string()
print(sample_text)
# Out:
#    Class  Alcohol  Malic_Acid   Ash  Alcalinity_of_Ash  Magnesium  Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  OD280_OD315  Proline
# 0      1    14.23        1.71  2.43               15.6        127           2.80        3.06                  0.28             2.29             5.64  1.04         3.92     1065
# 1      1    13.20        1.78  2.14               11.2        100           2.65        2.76                  0.26             1.28             4.38  1.05         3.40     1050
# 2      1    13.16        2.36  2.67               18.6        101           2.80        3.24                  0.30             2.81             5.68  1.03         3.17     1185
# 3      1    14.37        1.95  2.50               16.8        113           3.85        3.49                  0.24             2.18             7.80  0.86         3.45     1480
# ...

# %% [markdown]
# ## Experiment: Prompt-Based Data Summarization

# %% [markdown]
# EXPERIMENT 1: DATA SUMMARIZATION

# %% [markdown]
# Summarize the following wine dataset

# %% [markdown]
# The dataset contains multiple wine samples belonging to Class 1 with features such as alcohol content, acidity, phenols, and color intensity. The wines show variation in chemical composition, particularly in alcohol levels, flavonoid content, and proline concentration, which are important indicators of wine quality and classification.

# %% [markdown]
#  2. INSIGHT GENERATION

# %% [markdown]
# Analyze this dataset and provide 5 key insights.

# %% [markdown]
# 	1.	Alcohol content varies between samples and may influence wine strength.
# 	2.	Flavanoids and total phenols are relatively high, indicating good antioxidant properties.
# 	3.	Color intensity varies significantly, suggesting differences in wine richness.
# 	4.	Proline values vary widely, which may help distinguish wine types.
# 	5.	Magnesium levels are relatively consistent across samples.

# %% [markdown]
# 3. FEATURE IMPORTANCE

# %% [markdown]
# Which features are most important for classifying wine and why?

# %% [markdown]
# Important features include alcohol, flavanoids, color intensity, and proline. These attributes vary significantly across samples and are strongly related to wine composition and quality, making them useful for classification.

# %% [markdown]
#  4. SIMPLE EXPLANATION

# %% [markdown]
# Explain this dataset in simple terms for a beginner.

# %% [markdown]
# This dataset contains information about different wines and their chemical properties. Each row represents one wine sample, and each column shows a specific characteristic like alcohol level or acidity. These features help identify and classify different types of wine.

# %% [markdown]
#  5. GENERATIVE AI TASK

# %% [markdown]
# Generate a description of a wine with high alcohol and high color intensity.

# %% [markdown]
# This wine has a rich and bold character, with high alcohol content contributing to its strong taste. The high color intensity suggests a deep, vibrant appearance and a full-bodied flavor profile, often associated with premium quality wines.
